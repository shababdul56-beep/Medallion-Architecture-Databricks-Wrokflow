-- %% [markdown]
-- Order tables for Bronze

-- %%
select * from json.`/Volumes/ecomm/landing/opps_data_new/orders/`;

-- %%
select * from text.`/Volumes/ecomm/landing/opps_data_new/orders/`;

-- %%
create or replace view ecomm.bronze.v_orders as
select * from text.`/Volumes/ecomm/landing/opps_data_new/orders/`;

COMMENT ON VIEW ecomm.bronze.v_orders IS 'naming conventions from order to v_order and data cofmart changed'

-- %%
select * from ecomm.bronze.v_orders
