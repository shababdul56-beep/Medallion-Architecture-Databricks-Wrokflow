-- %%
%fs ls 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/landing/extrenal_data/payments'

-- %%
create table if not exists ecomm.bronze.payments
(payment_id  integer,
order_id  integer,
payment_timestamp  timestamp,
payment_status  integer,
payment_method  string)
using csv
options(
    hearder = "false", --try true
    delimiter = ','
)

LOCATION 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/landing/extrenal_data/payments'

-- %%
select * from ecomm.bronze.payments

-- %%
drop table if exists ecomm.bronze.payments
