# %%
# %fs ls

# %%
# %fs ls dbfs:/databricks-datasets/

# %%
dbutils.help()

# %%
# %fs ls 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/landing/customers'

# %%
# %sql show catalogs

# %%
# %sql 
create catalog if not exists ecomm
managed location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/'
comment 'first catalog created for ecomm mannually'

# %%
# %sql
select current_catalog()

# %%
# %sql
use catalog ecomm

# %%
# %sql
create schema if not exists landing
managed location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/landing'
comment 'landing zone for ecomm'

# %%
# %sql
create schema if not exists bronze
managed location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/bronze';
create schema if not exists silver
managed location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/silver';
create schema if not exists gold
managed location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/gold';

# %%
# %sql
show schemas

# %%
# %sql show databases;

# %%
# %sql
use catalog ecomm;
use schema landing;

create external volume if not exists Opps_data_new
location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/landing/opp_data/customer'

# %%
# %sql

drop external location if exists Opps_data_new

# %%
# %sql

drop external location if exists Opps_data

# %%
# %sql
use catalog ecomm;
use schema landing;

create external volume if not exists Opps_data_new
location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/landing/opp_data/'

# %%
# %fs ls /Volumes/ecomm/landing/opps_data_new/customers

# %%
# %sql
select * from json.`/Volumes/ecomm/landing/opps_data_new/customers`
# Out:
# Databricks data profile. Run in Databricks to view.

# %%
# %sql
create or replace view ecomm.bronze.v_customers as
select *, _metadata.file_path as filepath

from json.`/Volumes/ecomm/landing/opps_data_new/customers`

comment 'used naming convenstion for customers tables as V_customers in bronze layer'

# %%
# %sql
select * from ecomm.bronze.v_customers

# %%
# %sql
drop catalog if exists ecomm cascade
