-- %% [markdown]
-- ##Extract address Data

-- %%
select * from csv,`/Volumes/ecomm/landing/opps_data_new/addresses/`

-- %%
select * from csv.`/Volumes/ecomm/landing/opps_data_new/addresses/`

-- %%
select * from read_files.`/Volumes/ecomm/landing/opps_data_new/addresses/`

-- %%
select * from read_files('/Volumes/ecomm/landing/opps_data_new/addresses/', 
                        format => 'csv',
                        delimiter => '\t',
                        header => 'true');

-- %%
create or replace view ecomm.bronze.v_addresses
as 
select * from read_files('/Volumes/ecomm/landing/opps_data_new/addresses/', 
                        format => 'csv',
                        delimiter => '\t',
                        header => 'true');

-- %%
select * from ecomm.bronze.v_addresses
