-- %%
select * from ecomm.silver.adderesses

-- %%
select * from ecomm.silver.customers

-- %%
select ecomm.silver.adderesses.customer_id
from ecomm.silver.adderesses
inner join ecomm.silver.customers
on ecomm.silver.adderesses.customer_id = ecomm.silver.customers.customer_id
where ecomm.silver.customers.customer_id = ecomm.silver.adderesses.customer_id
