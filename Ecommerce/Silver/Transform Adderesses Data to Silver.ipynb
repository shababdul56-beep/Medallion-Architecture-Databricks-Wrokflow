-- %% [markdown]
-- Transform address data

-- %%
select * from ecomm.bronze.v_addresses

-- %%
select *
from (select customer_id,
address_type,
address_line_1,
city,
state,
postcode
from
ecomm.bronze.v_addresses)
pivot(
    max(address_line_1) as address_line_1,
    max(city) as city,
    max(state) as state,
    max(postcode) as postcode
    for address_type in ('shipping', 'billing')
);

-- %% [markdown]
-- Transform data to silver schema

-- %%
create table ecomm.silver.adderesses
as
select *
from (select customer_id,
address_type,
address_line_1,
city,
state,
postcode
from ecomm.bronze.v_addresses)
pivot(
    max(address_line_1) as address_line_1,
    max(city) as city,
    max(state) as state,
    max(postcode) as postcode
    for address_type in ('shipping', 'billing')
);

-- %%
select * from ecomm.silver.adderesses
