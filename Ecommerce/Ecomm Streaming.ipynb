-- %%
%sql show catalogs

-- %%
%fs ls

-- %%
%fs ls dbfs:/databricks-datasets/

-- %%
%fs ls 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/landing/opp_data/customers'

-- %% [markdown]
-- Catalog creation

-- %%
%sql
Create catalog if not exists ecomm
     managed location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net'
     comment 'This is for ecomm catalog'

-- %%
%sql
select current_catalog()

-- %%
%sql
Use catalog ecomm;

-- %%
%sql
create schema if not exists landing
managed location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net'

-- %%
%sql
create schema if not exists bronze
managed location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/bronze/';
create schema if not exists silver
managed location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/silver/';
create schema if not exists gold
managed location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/gold/';

-- %%
%sql
show schemas;

-- %% [markdown]
-- creating volume in landing

-- %%
%sql
use catalog ecomm;
use schema landing;

create external volume if not exists opp_data
location 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/landing/opp_data'

-- %%
Show volumes

-- %%
%sql
Select * from json.`abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/landing/opp_data/customers_stream`

-- %%
%fs ls 'abfss://layers@azdbsktsotrageacount.dfs.core.windows.net/ecomm/'
